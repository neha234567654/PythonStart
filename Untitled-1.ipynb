# %%
import pandas as pd

# %%
myData = { 'people' : ['John', 'Anna', 'Peter', 'Linda'],
           'age' : [24, 13, 53, 33],}

# %%
Frame = pd.DataFrame(myData)
print(Frame)
# Out:
#   people  age
# 0   John   24
# 1   Anna   13
# 2  Peter   53
# 3  Linda   33

# %%
df = pd.read_csv('GOOGL_stock_data (1).csv', parse_dates=['Date'])

# %%
display(df.head())
# Out:
#         Date    Open    High     Low   Close     Volume  Daily_Return_Pct  \
# 0 2004-08-19  2.4922  2.5846  2.3834  2.4837  893181924           -0.3411
# 1 2004-08-20  2.6901  2.7093  2.4962  2.5088  456686856           -6.7395
# 2 2004-08-23  2.7172  2.8185  2.7085  2.7507  365122512            1.2329
# 3 2004-08-24  2.6047  2.7718  2.5724  2.7629  304946748            6.0736
# 4 2004-08-25  2.6328  2.6824  2.5801  2.6069  183772044           -0.9837
#
#    Price_Range  Year  Month  Quarter Day_of_Week
# 0       0.2012  2004      8        3    Thursday
# 1       0.2131  2004      8        3      Friday
# 2       0.1100  2004      8        3      Monday
# 3       0.1994  2004      8        3     Tuesday
# 4       0.1023  2004      8        3   Wednesday

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5397 entries, 0 to 5396
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              5397 non-null   datetime64[ns]
#  1   Open              5397 non-null   float64
#  2   High              5397 non-null   float64
#  3   Low               5397 non-null   float64
#  4   Close             5397 non-null   float64
#  5   Volume            5397 non-null   int64
#  6   Daily_Return_Pct  5397 non-null   float64
#  7   Price_Range       5397 non-null   float64
#  8   Year              5397 non-null   int64
#  9   Month             5397 non-null   int64
#  10  Quarter           5397 non-null   int64
#  11  Day_of_Week       5397 non-null   object
# dtypes: datetime64[ns](1), float64(6), int64(4), object(1)
# memory usage: 802.4 KB

# %%
df.dtypes
# Out:
# Date                datetime64[ns]
# Open                       float64
# High                       float64
# Low                        float64
# Close                      float64
# Volume                       int64
# Daily_Return_Pct           float64
# Price_Range                float64
# Year                         int64
# Month                        int64
# Quarter                      int64
# Day_of_Week                 object
# dtype: object

# %%
# !pip install yfinance
# Out:
# ...
#   Using cached yfinance-1.2.0-py2.py3-none-any.whl.metadata (6.1 kB)
# ...
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# ...
#   Using cached multitasking-0.0.12.tar.gz (19 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached peewee-4.0.1-py3-none-any.whl.metadata (8.5 kB)
# ...
#   Using cached beautifulsoup4-4.14.3-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached curl_cffi-0.13.0-cp39-abi3-macosx_10_9_x86_64.whl.metadata (13 kB)
# ...
#   Using cached protobuf-7.34.0-cp310-abi3-macosx_10_9_universal2.whl.metadata (595 bytes)
# ...
# Using cached yfinance-1.2.0-py2.py3-none-any.whl (130 kB)
# Using cached curl_cffi-0.13.0-cp39-abi3-macosx_10_9_x86_64.whl (5.7 MB)
# Using cached beautifulsoup4-4.14.3-py3-none-any.whl (107 kB)
# ...
# Using cached peewee-4.0.1-py3-none-any.whl (139 kB)
# Using cached protobuf-7.34.0-cp310-abi3-macosx_10_9_universal2.whl (429 kB)
# ...

# %%
import numpy as np
import pandas as pd

import yfinance as yf
import matplotlib.pyplot as plt

# %%
x = np.random.normal(0,1,100)
x2 = np.random.normal(0,1,100)
plt.plot(x);
plt.plot(x2);
plt.xlabel("time")
plt.ylabel("Returns")
plt.legend(['x1', 'x2'])

# %%
np.mean(x)
# Out:
# np.float64(0.06578713049797563)

# %%
np.std(x)
# Out:
# np.float64(0.95261621215693)

# %%
data = yf.download("MSFT", start="2023-01-01", end="2026-03-12")
data
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open    Volume
# Ticker            MSFT        MSFT        MSFT        MSFT      MSFT
# Date
# 2023-01-03  233.452820  239.465022  231.328565  236.863308  25740000
# 2023-01-04  223.240845  226.914417  220.181150  226.339510  50623400
# 2023-01-05  216.624496  221.730491  216.088560  221.389436  39585600
# 2023-01-06  219.177460  219.986234  213.740180  217.296826  43613600
# 2023-01-09  221.311447  225.326089  220.619614  220.658584  27369800
# ...                ...         ...         ...         ...       ...
# 2026-03-05  410.679993  411.609985  404.399994  404.420013  39001300
# 2026-03-06  408.959991  413.049988  408.510010  409.200012  31123900
# 2026-03-09  409.410004  410.209991  403.500000  404.920013  30131900
# 2026-03-10  405.760010  410.200012  402.929993  410.029999  31706400
# ...

# %%
xprice = data['Close']

# %%
plt.plot(xprice.index, xprice.values);
plt.xlabel("time") 
plt.ylabel("Close Price")
plt.legend(['MSFT'])

# %%
np.mean(xprice)
# Out:
# np.float64(396.70888835348387)

# %%
np.std(xprice)
# Out:
# Ticker
# MSFT    73.972562
# dtype: float64

# %%
r = xprice.pct_change()[1:]

# %%
plt.hist(r, bins=20);
plt.xlabel("Returns")
plt.ylabel("Frequency")
plt.title("Distribution of MSFT Returns")
plt.legend(["MSFT Returns"])

# %%
MAVG = xprice.rolling(window=60).mean()
plt.plot(xprice.index, xprice.values);
plt.plot(MAVG.index, MAVG.values);
plt.ylabel("Close Price")
plt.legend(['MSFT', '60-day MAVG'])

# %%
import math
math.cos(math.pi / 2)
# Out:
# 6.123233995736766e-17

# %%
mylist = [1,2,3]
mylist1 = [4,5,6]
print(mylist)
mylist[0] = False
print(mylist)
mylist3 = mylist + mylist1
print(mylist3)
print(mylist3[::-1])
star = 0
sto = 10
ste = 2
my_list = range(star, sto, ste)
print(list(my_list))
# Out:
# [1, 2, 3]
# [False, 2, 3]
# [False, 2, 3, 4, 5, 6]
# [6, 5, 4, 3, 2, False]
# [0, 2, 4, 6, 8]

# %%
my_tuple = ('I', 'have', 30, 'cats')
print(my_tuple)
print(my_tuple[::2])
my_tuple2 = ('and', 'dogs')
my_tuple3 = my_tuple + my_tuple2
print(my_tuple3)
str_1, str_2 = my_tuple2
print(str_1, str_2)
# Out:
# ('I', 'have', 30, 'cats')
# ('I', 30)
# ('I', 'have', 30, 'cats', 'and', 'dogs')
# and dogs

# %%
stock_list = [3.5, 5, 2, 8, 4.2]

# %%
returns = np.array(stock_list)
print(returns)
# Out:
# [3.5 5.  2.  8.  4.2]

# %%
A = np.array([[1, 2], [3, 4]])
print(A.shape)
print(A[1,1])
print(A[0])
print(np.max(returns))
# Out:
# (2, 2)
# 4
# [1 2]
# 8.0
